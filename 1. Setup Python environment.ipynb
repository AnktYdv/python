# %% [markdown]
# # What is Python?
# Python is an interpreted high level programming language. It is often subclassified as a "scripting language" and is considered similar to languages such as Perl, Tcl, or Ruby. The syntax of Python is loosely inspired by elements of C programming.
#
# The primary difference between a scripting language and a programming language is in their execution – programming languages use a compiler to convert the complete high-level programming language program into machine language before executing, on the other hand, scripting languages use an interpreter to execute a scripting language program by converting one line at a time. Scripting language are often called to execute in REPL environment - *Read-Evaluate-Print Loop*.
#
# Python was created by Guido van Rossum around 1990 who named it in honor of Monty Python.

# %% [markdown]
# ## Running Python
# Python programs are executed by an interpreter. Usually, the interpreter is started by simply typing python into a command shell. You may like to start python interpreter by
# * starting command shell aka terminal.
# * cd to your training folder (e.g. "Python training"). This is for this tutorial only and is not essential at all. You can start Python shell from any folder.
# * Type "python" and press <Enter>

# %% [markdown]
# ![shell.PNG](attachment:shell.PNG)

# %% [markdown]
# ## Executing Python commands
# Python commands are executed by the interpreter vide
# * Python Shell
# * a file with ".py" extension
#
# For this tutorial, we will be using Jupyter notebook as explanatory notes and Python commands can very well be combined in a Jupyter notebook, making the learning very convenient, as we will see next in this lesson. However, in practice, we use a IDE, such as Pycharm, to create (and also test run) a Python program.
#
# Although, we will use Jupyter notebook to learn and test run Python commands, students are advised to use Pycharm for the same to gain real life experience.
#
# Let us run our first python command.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
"print" is the most commonly used Python function. Note that we use "print", all in small caps, followed by "()" and within 
"()", we specify we mention the arguments to be printed. Here "Hello World" is a string or alphanumeric arguments, hence 
mentioned within double quotes, although we can use single quotes also. 

For numeric arguments, we do not use quotes.

# %%
print(123)
print(456.78)
print(True)
# Out:
# 123
# 456.78
# True

# %% [markdown]
# To run above commands in a terminal, start Python shell and then input commands at the shell prompt.
# ![helloworld.PNG](attachment:helloworld.PNG)
#
# To run commands within Pycharm:
# * Start Pycharm
# * Right click Python Learning project -> Select New -> Select Python File. Give a file name such as test (withoyt .py extension)
# and hit Enter. A new file test.py will be created in the project folder. In right panel, you may then enter the print commands.
# * To run test.py, either right click file name in the right panel and then select run from the drop down menu or just press
# Ctrl-Shift-F10 (on some laptops, you may need to press Fn key also to select F10).
# * To close the Run console, either click the "-" button on the top right corner of the Run console or hit Shift-Escape.

# %% [markdown]
# ![pycharm1.PNG](attachment:pycharm1.PNG)

# %% [markdown]
# ![pycharm2.PNG](attachment:pycharm2.PNG)

# %% [markdown]
# ## Exercise
# ### Exercise 1.1
# Create a program to fetch some information from Amazon book store. It is fine if you do not understand the intricacies. Just type the lines in the Python shell or create a program in Pycharm. Use test.py as filename.
# ![1-1.PNG](attachment:1-1.PNG)
# Idea is to give you a feel of working in Python!

# %% [markdown]
# BTW, you can also use Python shell as a calculator!
# ```
# >>> (711.25 - 235.14) * 75
# 35708.25
# >>>
# ```
